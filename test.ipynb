# %% [markdown]
# <a href="https://colab.research.google.com/github/arvindbishnoii/arvindbishnoii/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# installing devito and importing modules 
#!pip install devito
#!pip install sympy
#!pip install numpy
#!pip install matplotlib
#!pip install pandas
import numpy as np
import sympy as sp
import pandas as pd
from sympy import *
from devito import *
from numpy import *


#A=100
#alpha = symbols(u'α')           # birth rate
#beta_e = symbols(u'β_e')        # the asymptomatic contact rate
#beta_i = symbols(u'β_i')        # is the symptomatic contact rate
#theta= symbols (u'θ')
#phi_e = symbols (u'Φ_e')       #  is the asymptomatic recovery rate
#phi_r = symbols (u'Φ_r')       # is the infected recovery rate
#phi_d = symbols (u'Φ_d')       # is the infected mortality rate
#sigma = symbols (u'σ')       # the inverse of the incubation period
#mu = symbols (u'μ')          # is the general (non-COVID-19) mortality rate

# declaring diffusion paramters as 1 for trial

#V_s = symbols (u'V_s')
#V_e = symbols (u'V_e')
#V_i = symbols (u'V_i')
#V_r = symbols (u'V_r')

# lets taks Alee coefficient as 1 for trial

#A = symbols (u'A')



# creating a grid
grid = Grid(shape=(100,100), extent=(1,1))
grid
#grid1=Grid(shape(50), extent=(1))



# for creating time function

#susceptible (S), exposed (E), infected (I), Recovered (R) and Dead (D). 
#The system of equations in the SEIRD model is given by:
S = TimeFunction(name='S', grid=grid,space_order=1,time_order=1)

E = TimeFunction(name='E', grid=grid,space_order=1,time_order=1)

I = TimeFunction(name='I', grid=grid,space_order=1,time_order=1)

R = TimeFunction(name='R', grid=grid,space_order=1,time_order=1)

D = TimeFunction(name='D', grid=grid,space_order=1,time_order=1)

alpha=TimeFunction(name='alpha', grid=grid,time_order=1,save=1000)
beta=TimeFunction(name='beta', grid=grid,time_order=1,save=100)
Rep_num=TimeFunction(name='Rep_num', grid=grid,time_order=1,save=100)

#g.shape

N = S + E + I + R + D
N = TimeFunction(name='N', grid=grid,space_order=1,time_order=1)
# where N is the total population, i.e. N = S + E + I + R + D at each time t

# %%
#Eq1=Eq(S.dt, - (D)/N * S* I)
#Eq1
#After giving some values to d,n,s,i

Eq1=Eq(S.dt, - (10)/50 * 20* 10)
Eq1
# Out:
# Eq(Derivative(S(t, x, y), t), -40.0000000000000)

# %%
from examples.seismic import TimeAxis

t0 = 0.  # Simulation starts a t=0
tn = 1000.  # Simulation last 1 second (1000 ms)
dt = 1.           # Time step from model grid spacing

time_range = TimeAxis(start=t0, stop=tn, step=dt)

# %%
stencil = solve(Eq1, S.forward)
update = Eq(S.forward, stencil)
update
# Out:
# Eq(S(t + dt, x, y), dt*(-40.0 + S(t, x, y)/dt))

# %%
stencil
# Out:
# dt*(-40.0 + S(t, x, y)/dt)

# %%
op = Operator(update, opt="noop")
op
# Out:
# Cpu64NoopCOperator[Kernel]<int; struct dataobj *,const float,const int,const int,const int,const int,const int,const int,struct profiler *>

# %%
op(time=20, dt=dt)
# Out:
# Operator `Kernel` ran in 0.01 s
# PerformanceSummary([(PerfKey(name='section0', rank=None),
#                      PerfEntry(time=0.00010500000000000005, gflopss=0.0, gpointss=0.0, oi=0.0, ops=0, itershapes=[]))])

# %%
S.data[20]

#value of s after 20 timestamps
# Out:
# Data([[-800., -800., -800., ..., -800., -800., -800.],
#       [-800., -800., -800., ..., -800., -800., -800.],
#       [-800., -800., -800., ..., -800., -800., -800.],
#       ...,
#       [-800., -800., -800., ..., -800., -800., -800.],
#       [-800., -800., -800., ..., -800., -800., -800.],
#       [-800., -800., -800., ..., -800., -800., -800.]], dtype=float32)

# %%
print(op.ccode)
# Out:
# #define _POSIX_C_SOURCE 200809L
# #define START_TIMER(S) struct timeval start_ ## S , end_ ## S ; gettimeofday(&start_ ## S , NULL);
# #define STOP_TIMER(S,T) gettimeofday(&end_ ## S, NULL); T->S += (double)(end_ ## S .tv_sec-start_ ## S.tv_sec)+(double)(end_ ## S .tv_usec-start_ ## S .tv_usec)/1000000;
#
# #include "stdlib.h"
# #include "math.h"
# #include "sys/time.h"
#
# struct dataobj
# {
#   void *restrict data;
#   int * size;
#   int * npsize;
#   int * dsize;
#   int * hsize;
#   int * hofs;
#   int * oofs;
# } ;
#
# struct profiler
# {
#   double section0;
# } ;
#
#
# int Kernel(struct dataobj *restrict S_vec, const float dt, const int time_M, const int time_m, const int x_M, const int x_m, const int y_M, const int y_m, struct profiler * timers)
# {
#   float (*restrict S)[S_vec->size[1]][S_vec->size[2]] __attribute__ ((aligned (64))) = (float (*)[S_vec->size[1]][S_vec->size[2]]) S_vec->data;
#
#   for (int time = time_m, t0 = (time)%(2), t1 = (time + 1)%(2); time <= time_M; time += 1, t0 = (time)%(2), t1 = (time + 1)%(2))
#   {
#     /* Begin section0 */
#     START_TIMER(section0)
#     for (int x = x_m; x <= x_M; x += 1)
#     {
#       for (int y = y_m; y <= y_M; y += 1)
#       {
#         S[t1][x + 1][y + 1] = dt*(-4.0e+1F + S[t0][x + 1][y + 1]/dt);
#       }
#     }
#     STOP_TIMER(section0,timers)
#     /* End section0 */
#   }
#
#   return 0;
# }

# %% [markdown]
# Model parameters estimation-

# %%
# vector stack

a = np.array([[1], [2], [3]])
f = np.array([[1], [2], [3]])
rho = np.array([[1], [2], [3]])

stacked_vectors=np.vstack((a,f,rho))
stacked_vectors

i = np.array([[320], [396], [472]])
r = np.array([[24], [24], [32]])
d = np.array([[13], [16], [19]])

stacked_vectors1=np.vstack((i,r,d))
stacked_vectors1
# Out:
# array([[320],
#        [396],
#        [472],
#        [ 24],
#        [ 24],
#        [ 32],
#        [ 13],
#        [ 16],
#        [ 19]])

# %%
a = np.array([1, 2, 3])
f = np.array([1, 2, 3])
rho = np.array([1, 2,3])

stacked_vectors=np.vstack((a,f,rho))
stacked_vectors

i = np.array([320, 396, 472])
r = np.array([24, 24, 32])
d = np.array([13, 16, 19])

stacked_vectors1=np.vstack((i,r,d))
stacked_vectors1
# Out:
# array([[320, 396, 472],
#        [ 24,  24,  32],
#        [ 13,  16,  19]])

# %%
#perimeter estimation a,f,rho
'''
def u(v):
  a = np.array([1,2, 3])
  f = np.array([1, 2, 3])
  rho = np.array([1, 2, 3])
  v=np.vstack((a,f,rho))
  return v
'''
def fun_rosenbrock(x):
    return np.array([100 * x[0],5-x[1],5*x[2]])

#return np.array([10 * (x[1] - x[0]**2), (1 - x[0]) , (3 - x[2])])

from scipy.optimize import least_squares
i = np.array([320, 396, 472])
r = np.array([24, 24, 32])
d = np.array([13, 16, 19])
n = np.array([i[0],r[0],d[0]])
Y=np.vstack((i,r,d))
stacked_vectors1
res_1 = leastsq(fun_rosenbrock, n)
res_1
# Out:
# (array([-3.32053644e-33,  5.00000000e+00, -1.34887977e-34]), 2)

# %%
from scipy.optimize import leastsq
def func(x):
    return 2*(x-3)**2+1
leastsq(func, 0)
# Out:
# (array([2.99999999]), 1)

# %%
import numpy as np
from numpy import exp
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.special import factorial
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import statsmodels.api as sm
from statsmodels.api import Poisson
from scipy import stats
from scipy.stats import norm
from statsmodels.iolib.summary2 import summary_col

i = np.array([320, 396, 472])
r = np.array([24, 24, 32])
d = np.array([13, 16, 19])
 # x = np.array([320, 32, 19])
X=np.vstack((i[0],r[0],d[0]))

y = np.array([1, 2, 3])

stats_poisson = Poisson(y, X).fit()
print(stats_poisson.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 1.824455
#          Iterations 4
#                           Poisson Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                    3
# Model:                        Poisson   Df Residuals:                        2
# Method:                           MLE   Df Model:                            0
# Date:                Sat, 23 Jul 2022   Pseudo R-squ.:                 -0.2652
# Time:                        22:07:12   Log-Likelihood:                -5.4734
# converged:                       True   LL-Null:                       -4.3260
# Covariance Type:            nonrobust   LLR p-value:                       nan
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0005      0.003      0.156      0.876      -0.005       0.006
# ==============================================================================

# %%
shape=(10,10)
be=np.empty(shape=shape )

# We can now write the PDE
S.dt =  -beta * 20 * 60 / 100
S.dt
# Out:
# -12*beta(time, x, y)

# %%
df1=pd.read_csv('/content/dpc-covid19-ita-regioni new.csv')  
df1.head(50)
# Out:
#                    data stato  region_code                 region        lat  \
# 0   2020-02-24T18:00:00   ITA           13                Abruzzo  42.351222
# 1   2020-02-24T18:00:00   ITA           17             Basilicata  40.639471
# 2   2020-02-24T18:00:00   ITA           18               Calabria  38.905976
# 3   2020-02-24T18:00:00   ITA           15               Campania  40.839566
# 4   2020-02-24T18:00:00   ITA            8         Emilia-Romagna  44.494367
# 5   2020-02-24T18:00:00   ITA            6  Friuli Venezia Giulia  45.649435
# 6   2020-02-24T18:00:00   ITA           12                  Lazio  41.892770
# 7   2020-02-24T18:00:00   ITA            7                Liguria  44.411493
# 8   2020-02-24T18:00:00   ITA            3              Lombardia  45.466794
# 9   2020-02-24T18:00:00   ITA           11                 Marche  43.616760
# 10  2020-02-24T18:00:00   ITA           14                 Molise  41.557748
# 11  2020-02-24T18:00:00   ITA           21           P.A. Bolzano  46.499335
# 12  2020-02-24T18:00:00   ITA           22            P.A. Trento  46.068935
# 13  2020-02-24T18:00:00   ITA            1               Piemonte  45.073274
# 14  2020-02-24T18:00:00   ITA           16                 Puglia  41.125596
# 15  2020-02-24T18:00:00   ITA           20               Sardegna  39.215312
# 16  2020-02-24T18:00:00   ITA           19                Sicilia  38.115697
# 17  2020-02-24T18:00:00   ITA            9                Toscana  43.769231
# 18  2020-02-24T18:00:00   ITA           10                 Umbria  43.106758
# 19  2020-02-24T18:00:00   ITA            2          Valle d'Aosta  45.737503
# 20  2020-02-24T18:00:00   ITA            5                 Veneto  45.434905
# 21  2020-02-25T18:00:00   ITA           13                Abruzzo  42.351222
# 22  2020-02-25T18:00:00   ITA           17             Basilicata  40.639471
# 23  2020-02-25T18:00:00   ITA           18               Calabria  38.905976
# 24  2020-02-25T18:00:00   ITA           15               Campania  40.839566
# 25  2020-02-25T18:00:00   ITA            8         Emilia-Romagna  44.494367
# 26  2020-02-25T18:00:00   ITA            6  Friuli Venezia Giulia  45.649435
# 27  2020-02-25T18:00:00   ITA           12                  Lazio  41.892770
# 28  2020-02-25T18:00:00   ITA            7                Liguria  44.411493
# 29  2020-02-25T18:00:00   ITA            3              Lombardia  45.466794
# 30  2020-02-25T18:00:00   ITA           11                 Marche  43.616760
# 31  2020-02-25T18:00:00   ITA           14                 Molise  41.557748
# 32  2020-02-25T18:00:00   ITA           21           P.A. Bolzano  46.499335
# 33  2020-02-25T18:00:00   ITA           22            P.A. Trento  46.068935
# 34  2020-02-25T18:00:00   ITA            1               Piemonte  45.073274
# 35  2020-02-25T18:00:00   ITA           16                 Puglia  41.125596
# 36  2020-02-25T18:00:00   ITA           20               Sardegna  39.215312
# 37  2020-02-25T18:00:00   ITA           19                Sicilia  38.115697
# 38  2020-02-25T18:00:00   ITA            9                Toscana  43.769231
# 39  2020-02-25T18:00:00   ITA           10                 Umbria  43.106758
# 40  2020-02-25T18:00:00   ITA            2          Valle d'Aosta  45.737503
# 41  2020-02-25T18:00:00   ITA            5                 Veneto  45.434905
# 42  2020-02-26T18:00:00   ITA           13                Abruzzo  42.351222
# 43  2020-02-26T18:00:00   ITA           17             Basilicata  40.639471
# 44  2020-02-26T18:00:00   ITA           18               Calabria  38.905976
# 45  2020-02-26T18:00:00   ITA           15               Campania  40.839566
# 46  2020-02-26T18:00:00   ITA            8         Emilia-Romagna  44.494367
# 47  2020-02-26T18:00:00   ITA            6  Friuli Venezia Giulia  45.649435
# 48  2020-02-26T18:00:00   ITA           12                  Lazio  41.892770
# 49  2020-02-26T18:00:00   ITA            7                Liguria  44.411493
#
#          long  hospitalized with symptoms  intensive care  total hospitalized  \
# 0   13.398438                           0               0                   0
# 1   15.805148                           0               0                   0
# 2   16.594402                           0               0                   0
# 3   14.250850                           0               0                   0
# 4   11.341721                          10               2                  12
# 5   13.768136                           0               0                   0
# 6   12.483667                           1               1                   2
# 7    8.932699                           0               0                   0
# 8    9.190347                          76              19                  95
# 9   13.518875                           0               0                   0
# 10  14.659161                           0               0                   0
# 11  11.356624                           0               0                   0
# 12  11.121231                           0               0                   0
# 13   7.680687                           2               0                   2
# 14  16.867367                           0               0                   0
# 15   9.110616                           0               0                   0
# 16  13.362357                           0               0                   0
# 17  11.255889                           0               0                   0
# 18  12.388247                           0               0                   0
# 19   7.320149                           0               0                   0
# 20  12.338452                          12               4                  16
# 21  13.398438                           0               0                   0
# 22  15.805148                           0               0                   0
# 23  16.594402                           0               0                   0
# 24  14.250850                           0               0                   0
# 25  11.341721                          15               2                  17
# 26  13.768136                           0               0                   0
# 27  12.483667                           1               1                   2
# 28   8.932699                           1               0                   1
# 29   9.190347                          79              25                 104
# 30  13.518875                           0               0                   0
# 31  14.659161                           0               0                   0
# 32  11.356624                           1               0                   1
# 33  11.121231                           0               0                   0
# 34   7.680687                           2               0                   2
# 35  16.867367                           0               0                   0
# 36   9.110616                           0               0                   0
# 37  13.362357                           1               0                   1
# 38  11.255889                           2               0                   2
# 39  12.388247                           0               0                   0
# 40   7.320149                           0               0                   0
# 41  12.338452                          12               7                  19
# 42  13.398438                           0               0                   0
# 43  15.805148                           0               0                   0
# 44  16.594402                           0               0                   0
# 45  14.250850                           0               0                   0
# 46  11.341721                          20               3                  23
# 47  13.768136                           0               0                   0
# 48  12.483667                           0               0                   0
# 49   8.932699                           6               0                   6
#
#     home isolation  ...  note  intensive care entrances  note_test  \
# 0                0  ...   NaN                       NaN        NaN
# 1                0  ...   NaN                       NaN        NaN
# 2                0  ...   NaN                       NaN        NaN
# 3                0  ...   NaN                       NaN        NaN
# 4                6  ...   NaN                       NaN        NaN
# 5                0  ...   NaN                       NaN        NaN
# 6                0  ...   NaN                       NaN        NaN
# 7                0  ...   NaN                       NaN        NaN
# 8               71  ...   NaN                       NaN        NaN
# 9                0  ...   NaN                       NaN        NaN
# 10               0  ...   NaN                       NaN        NaN
# 11               0  ...   NaN                       NaN        NaN
# 12               0  ...   NaN                       NaN        NaN
# 13               1  ...   NaN                       NaN        NaN
# 14               0  ...   NaN                       NaN        NaN
# 15               0  ...   NaN                       NaN        NaN
# 16               0  ...   NaN                       NaN        NaN
# 17               0  ...   NaN                       NaN        NaN
# 18               0  ...   NaN                       NaN        NaN
# 19               0  ...   NaN                       NaN        NaN
# 20              16  ...   NaN                       NaN        NaN
# 21               0  ...   NaN                       NaN        NaN
# 22               0  ...   NaN                       NaN        NaN
# 23               0  ...   NaN                       NaN        NaN
# 24               0  ...   NaN                       NaN        NaN
# 25               9  ...   NaN                       NaN        NaN
# 26               0  ...   NaN                       NaN        NaN
# 27               0  ...   NaN                       NaN        NaN
# 28               0  ...   NaN                       NaN        NaN
# 29             127  ...   NaN                       NaN        NaN
# 30               0  ...   NaN                       NaN        NaN
# 31               0  ...   NaN                       NaN        NaN
# 32               0  ...   NaN                       NaN        NaN
# 33               0  ...   NaN                       NaN        NaN
# 34               1  ...   NaN                       NaN        NaN
# 35               0  ...   NaN                       NaN        NaN
# 36               0  ...   NaN                       NaN        NaN
# 37               2  ...   NaN                       NaN        NaN
# 38               0  ...   NaN                       NaN        NaN
# 39               0  ...   NaN                       NaN        NaN
# 40               0  ...   NaN                       NaN        NaN
# 41              23  ...   NaN                       NaN        NaN
# 42               0  ...   NaN                       NaN        NaN
# 43               0  ...   NaN                       NaN        NaN
# 44               0  ...   NaN                       NaN        NaN
# 45               0  ...   NaN                       NaN        NaN
# 46              23  ...   NaN                       NaN        NaN
# 47               0  ...   NaN                       NaN        NaN
# 48               0  ...   NaN                       NaN        NaN
# 49               5  ...   NaN                       NaN        NaN
#
#     note_cases  total_positives_molecular_test  \
# 0          NaN                             NaN
# 1          NaN                             NaN
# 2          NaN                             NaN
# 3          NaN                             NaN
# 4          NaN                             NaN
# 5          NaN                             NaN
# 6          NaN                             NaN
# 7          NaN                             NaN
# 8          NaN                             NaN
# 9          NaN                             NaN
# 10         NaN                             NaN
# 11         NaN                             NaN
# 12         NaN                             NaN
# 13         NaN                             NaN
# 14         NaN                             NaN
# 15         NaN                             NaN
# 16         NaN                             NaN
# 17         NaN                             NaN
# 18         NaN                             NaN
# 19         NaN                             NaN
# 20         NaN                             NaN
# 21         NaN                             NaN
# 22         NaN                             NaN
# 23         NaN                             NaN
# 24         NaN                             NaN
# 25         NaN                             NaN
# 26         NaN                             NaN
# 27         NaN                             NaN
# 28         NaN                             NaN
# 29         NaN                             NaN
# 30         NaN                             NaN
# 31         NaN                             NaN
# 32         NaN                             NaN
# 33         NaN                             NaN
# 34         NaN                             NaN
# 35         NaN                             NaN
# 36         NaN                             NaN
# 37         NaN                             NaN
# 38         NaN                             NaN
# 39         NaN                             NaN
# 40         NaN                             NaN
# 41         NaN                             NaN
# 42         NaN                             NaN
# 43         NaN                             NaN
# 44         NaN                             NaN
# 45         NaN                             NaN
# 46         NaN                             NaN
# 47         NaN                             NaN
# 48         NaN                             NaN
# 49         NaN                             NaN
#
#     total positive rapid antigen test  molecular test swabs  \
# 0                                 NaN                   NaN
# 1                                 NaN                   NaN
# 2                                 NaN                   NaN
# 3                                 NaN                   NaN
# 4                                 NaN                   NaN
# 5                                 NaN                   NaN
# 6                                 NaN                   NaN
# 7                                 NaN                   NaN
# 8                                 NaN                   NaN
# 9                                 NaN                   NaN
# 10                                NaN                   NaN
# 11                                NaN                   NaN
# 12                                NaN                   NaN
# 13                                NaN                   NaN
# 14                                NaN                   NaN
# 15                                NaN                   NaN
# 16                                NaN                   NaN
# 17                                NaN                   NaN
# 18                                NaN                   NaN
# 19                                NaN                   NaN
# 20                                NaN                   NaN
# 21                                NaN                   NaN
# 22                                NaN                   NaN
# 23                                NaN                   NaN
# 24                                NaN                   NaN
# 25                                NaN                   NaN
# 26                                NaN                   NaN
# 27                                NaN                   NaN
# 28                                NaN                   NaN
# 29                                NaN                   NaN
# 30                                NaN                   NaN
# 31                                NaN                   NaN
# 32                                NaN                   NaN
# 33                                NaN                   NaN
# 34                                NaN                   NaN
# 35                                NaN                   NaN
# 36                                NaN                   NaN
# 37                                NaN                   NaN
# 38                                NaN                   NaN
# 39                                NaN                   NaN
# 40                                NaN                   NaN
# 41                                NaN                   NaN
# 42                                NaN                   NaN
# 43                                NaN                   NaN
# 44                                NaN                   NaN
# 45                                NaN                   NaN
# 46                                NaN                   NaN
# 47                                NaN                   NaN
# 48                                NaN                   NaN
# 49                                NaN                   NaN
#
#     rapid antigen test swabs  codice_nuts_1  codice_nuts_2
# 0                        NaN            NaN            NaN
# 1                        NaN            NaN            NaN
# 2                        NaN            NaN            NaN
# 3                        NaN            NaN            NaN
# 4                        NaN            NaN            NaN
# 5                        NaN            NaN            NaN
# 6                        NaN            NaN            NaN
# 7                        NaN            NaN            NaN
# 8                        NaN            NaN            NaN
# 9                        NaN            NaN            NaN
# 10                       NaN            NaN            NaN
# 11                       NaN            NaN            NaN
# 12                       NaN            NaN            NaN
# 13                       NaN            NaN            NaN
# 14                       NaN            NaN            NaN
# 15                       NaN            NaN            NaN
# 16                       NaN            NaN            NaN
# 17                       NaN            NaN            NaN
# 18                       NaN            NaN            NaN
# 19                       NaN            NaN            NaN
# 20                       NaN            NaN            NaN
# 21                       NaN            NaN            NaN
# 22                       NaN            NaN            NaN
# 23                       NaN            NaN            NaN
# 24                       NaN            NaN            NaN
# 25                       NaN            NaN            NaN
# 26                       NaN            NaN            NaN
# 27                       NaN            NaN            NaN
# 28                       NaN            NaN            NaN
# 29                       NaN            NaN            NaN
# 30                       NaN            NaN            NaN
# 31                       NaN            NaN            NaN
# 32                       NaN            NaN            NaN
# 33                       NaN            NaN            NaN
# 34                       NaN            NaN            NaN
# 35                       NaN            NaN            NaN
# 36                       NaN            NaN            NaN
# 37                       NaN            NaN            NaN
# 38                       NaN            NaN            NaN
# 39                       NaN            NaN            NaN
# 40                       NaN            NaN            NaN
# 41                       NaN            NaN            NaN
# 42                       NaN            NaN            NaN
# 43                       NaN            NaN            NaN
# 44                       NaN            NaN            NaN
# 45                       NaN            NaN            NaN
# 46                       NaN            NaN            NaN
# 47                       NaN            NaN            NaN
# 48                       NaN            NaN            NaN
# 49                       NaN            NaN            NaN
#
# [50 rows x 30 columns]

# %%
import numpy as np
from numpy import linalg as LA

# Our data
A = np.array([[1, 4, 16], [1, 0, 0], [1, 1, 1]])

y = np.array([[5], [1], [3]])

theta = LA.lstsq(A, y)

print(theta)
# Out:
# (array([[ 1.        ],
#        [ 2.33333333],
#        [-0.33333333]]), array([], dtype=float64), 3, array([16.5718975 ,  1.45791727,  0.49667938]))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   if __name__ == '__main__':

# %%
from sklearn.metrics import mean_squared_error

y_actual = [11,27,41]

y_predicted = [69,102,136]

rms = mean_squared_error(y_actual, y_predicted, squared=False)
rms
# Out:
# 77.48978427293927
